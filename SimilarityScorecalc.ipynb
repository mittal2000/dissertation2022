# %% [markdown]
# <a href="https://colab.research.google.com/github/mittal2000/dissertation2022/blob/main/SimilarityScorecalc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# %%
print(torch.__version__)
# Out:
# 1.11.0+cu113

# %%
# !pip install git+https://github.com/pmorris2012/CLIPEmbedding.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/pmorris2012/CLIPEmbedding.git to /tmp/pip-req-build-jw2mkyh0
#   Running command git clone -q https://github.com/pmorris2012/CLIPEmbedding.git /tmp/pip-req-build-jw2mkyh0
# ...
#      |████████████████████████████████| 53 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 20.3 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.2 MB/s
# ...
#   Created wheel for CLIPEmbedding: filename=CLIPEmbedding-0.0.1-py3-none-any.whl size=14801 sha256=18d424bbdf59982e87ae52e0ec4171dc13660eff6f52597181fadcb970c0437b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-erztrk7a/wheels/b8/c6/5d/6c20895acfdd3eddf2d63040b43b3b2fdfd40fe38f2a6d1669
# Successfully built CLIPEmbedding
# ...
#   Attempting uninstall: pyyaml
# ...

# %%
from CLIPEmbedding import CLIPEmbedding
from skimage.io import imread

clip = CLIPEmbedding(
    model_path="openai/clip-vit-base-patch32", #🤗 Transformers URI or Path to checkpoint file
    device='cpu' #defaults to 'cpu'
)

im = imread("https://picsum.photos/224/224")

im = clip.embed_images([im]) #list of PIL Images, numpy arrays, or torch Tensors
text = clip.embed_text(["red", "blue", "green", "yellow"])

print(im.shape) #(1, 512)
print(text.shape) #(4, 512)

scores = clip.similarity(im, text, softmax=True)
print(scores.shape) #(1, 4)
# Out:
# Downloading:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/577M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/389 [00:00<?, ?B/s]
# torch.Size([1, 512])
# torch.Size([4, 512])
# torch.Size([1, 4])

# %%
print(scores)
# Out:
# tensor([[0.0078, 0.0061, 0.9741, 0.0120]])

# %%
im = imread("https://e0.365dm.com/22/06/2048x1152/skysports-gabriel-jesus-manchester-city_5794582.jpg?20220604091951")

im = clip.embed_images([im]) #list of PIL Images, numpy arrays, or torch Tensors
# text = clip.embed_text(['The gap between Irish home prices and household income was at its widest since 2008 at the end of last year. Photograph: Alan Betson'])
text = clip.embed_text(['man', 'blue', 'Tottenham join race to sign Man City\'s Gabriel Jesus - Paper Talk', 'Gabriel Jesus could leave Manchester City this summer', 'Gabriel Jesus is at the centre of a tug of war between north London rivals Arsenal and Spurs.'])
print(im.shape) #(1, 512)
print(text.shape) #(4, 512)

scores = clip.similarity(im, text, softmax=True)
print(scores.shape) #(1, 4)

print(scores)
# Out:
# torch.Size([1, 512])
# torch.Size([5, 512])
# torch.Size([1, 5])
# tensor([[7.2631e-06, 8.7845e-06, 3.6647e-01, 3.8642e-01, 2.4709e-01]])
