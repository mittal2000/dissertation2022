# %% [markdown]
# <a href="https://colab.research.google.com/github/mittal2000/dissertation2022/blob/main/pygooglenewsworking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pygooglenews --upgrade
# Out:
# Collecting pygooglenews
#   Using cached pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Collecting feedparser<6.0.0,>=5.2.1
#   Using cached feedparser-5.2.1.zip (1.2 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       error in feedparser setup command: use_2to3 is invalid.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import requests
import pandas as pd
import re 
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession 
from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
import requests
import pandas as pd
import re 
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession 
from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
from PIL import Image
import requests
from io import BytesIO

import os, json, cv2, random

gn = GoogleNews()
search = gn.search('michael jackson')
i = 1
data = []
column = ['article_title', 'article_link', 'image_link(s)', 'image_caption(s)', 'classification(s)']
data.append(column)
for item in search['entries']:
    if i == 10:
        break
    column = []
    URL = item.link
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    links = []
    captions = []
    if(soup.find('title').text != ''):
        column.append(soup.find('title').text)
    elif (soup.find('h1').text != ''):
        column.append(soup.find('h1').text)
    column.append(URL)
    if (soup.findAll('img') != ' '):
        for link in soup.findAll('img'):
            captions.append(link.get('alt'))
            lelink = link.get('src')
            links.append(lelink)
            try:
                urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
            except:
                print('Mayday mayday')
    elif (soup.findAll('figure') != ' '):
        for link in soup.findAll('figure'):
            print('the img thing was empty')
            captions.append(link.get('alt'))
            lelink = link.get('src')
            links.append(lelink)
            try:
                urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
            except:
                print('Mayday mayday')
    column.append(links)
    column.append(captions)
    data.append(column)
    i = i + 1
import pandas as pd
column = ['article_title', 'article_link', 'image_link(s)', 'image_caption(s)', 'classification(s)']
df = pd.DataFrame(data, columns=column)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       5 from bs4 import BeautifulSoup
#       6 from requests_html import HTMLSession
# ----> 7 from pygooglenews import GoogleNews
#       8 import requests
#       9 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'pygooglenews'

# %%
df
# Out:
#                                        article_title  \
# 0                                      article_title
# 1  Chris Brown Addresses People Comparing Him to ...
# 2  Klay Thompson does great Michael Jackson dance...
# 3    Robins announces Heart, Michael Jackson trib...
# 4  Michael Jackson show brings alumni on stage | ...
# 5  Michael Jackson’s ‘Thriller’ Jacket Enters Roc...
# 6                                        nytimes.com
# 7  Michael Jackson's Daughter Paris Jackson Once ...
# 8  Paris Jackson, Prince Jackson Honor Michael Ja...
# 9  Myles Frost was born to play Michael Jackson. ...
#
#                                         article_link  \
# 0                                       article_link
# 1  https://www.complex.com/music/chris-brown-addr...
# 2  https://www.nbcsports.com/bayarea/warriors/kla...
# 3  https://www.tribtoday.com/life/ticket/2022/06/...
# 4  http://www.ladowntownnews.com/arts_and_enterta...
# 5  https://www.billboard.com/music/music-news/mic...
# 6  https://www.nytimes.com/2022/06/02/arts/dance/...
# 7  https://www.cheatsheet.com/entertainment/micha...
# 8  https://www.today.com/popculture/awards/paris-...
# 9  https://www.washingtonpost.com/theater-dance/2...
#
#                                        image_link(s)  \
# 0                                      image_link(s)
# 1  [data:image/svg+xml,%3Csvg xmlns="http://www.w...
# 2  [https://www.nbcsports.com/sites/rsnunited/fil...
# 3  [https://www.tribtoday.com/wp-content/themes/c...
# 4  [......
# 5  [https://www.facebook.com/tr?id=20465255320266...
# 6                                                 []
# 7  [https://www.cheatsheet.com/wp-content/uploads...
# 8  [https://media-cldnry.s-nbcnews.com/image/uplo...
# 9                                             [None]
#
#                                     image_caption(s)  classification(s)
# 0                                   image_caption(s)  classification(s)
# 1  [Chris Brown and Wizkid "Call Me Every Day", L...               None
# 2           [, Powered by Xfinity, None, , , , None]               None
# 3  [homepage logo, None, homepage logo, None, Non...               None
# 4  [, , Rodrigo Teaser, Rodrigo Teaser, Barenaked...               None
# 5  [None, None, Michael Jackson "Thriller", , Mic...               None
# 6                                                 []               None
# 7  [Showbiz Cheat Sheet, Paris Jackson performing...               None
# 8  [Food, Style, Health, Parenting, Home, Pop, Sh...               None
# 9                                                 []               None

# %%
# !pip3 install requests-html
# Out:
# Collecting requests-html
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting fake-useragent
#   Using cached fake_useragent-0.1.11-py3-none-any.whl
# Collecting parse
#   Using cached parse-1.19.0-py3-none-any.whl
# Collecting pyquery
#   Using cached pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting bs4
#   Using cached bs4-0.0.1-py3-none-any.whl
# Collecting w3lib
#   Using cached w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting pyppeteer>=0.0.14
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests-html) (2.27.1)
# Requirement already satisfied: certifi>=2021 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (2021.10.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (4.63.0)
# Collecting appdirs<2.0.0,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-4.11.4-py3-none-any.whl (18 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (1.26.9)
# Collecting pyee<9.0.0,>=8.1.0
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: websockets<11.0,>=10.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html) (10.3)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from bs4->requests-html) (4.11.1)
# Collecting cssselect>0.7.9
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting lxml>=2.1
#   Downloading lxml-4.9.0.tar.gz (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 5.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->requests-html) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->requests-html) (3.3)
# Requirement already satisfied: six>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from w3lib->requests-html) (1.16.0)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests-html) (2.3.1)
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.0-cp39-cp39-macosx_11_0_arm64.whl size=1444187 sha256=2a1f6882291a3bc06201f2d5c391b9f3794dfe2f9eaaa8024ddd2e72f0eb006e
#   Stored in directory: /Users/ben/Library/Caches/pip/wheels/51/e7/8f/449fb7c30cec16495fa25330c905328f89d27c4e3c0306c418
# Successfully built lxml
# Installing collected packages: pyee, parse, fake-useragent, appdirs, zipp, w3lib, lxml, cssselect, pyquery, importlib-metadata, bs4, pyppeteer, requests-html
# Successfully installed appdirs-1.4.4 bs4-0.0.1 cssselect-1.1.0 fake-useragent-0.1.11 importlib-metadata-4.11.4 lxml-4.9.0 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 w3lib-1.22.0 zipp-3.8.0
