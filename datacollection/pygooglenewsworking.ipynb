# %% [markdown]
# <a href="https://colab.research.google.com/github/mittal2000/dissertation2022/blob/main/pygooglenewsworking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygooglenews --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygooglenews
#   Downloading pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Collecting feedparser<6.0.0,>=5.2.1
#   Downloading feedparser-5.2.1.zip (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.3 MB/s
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 21.0 MB/s
# Collecting dateparser<0.8.0,>=0.7.6
#   Downloading dateparser-0.7.6-py2.py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 73.2 MB/s
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->pygooglenews) (2.3.2.post1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.1)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44952 sha256=c647932d4f7d7ed1a55e8f02cb231b9fac5570b7da364a64a4c9907b1f1002cc
#   Stored in directory: /root/.cache/pip/wheels/29/bf/46/b4a597d435d3aee6c2fa583824897336d65abf13ebe3405b70
# Successfully built feedparser
# Installing collected packages: requests, feedparser, dateparser, beautifulsoup4, pygooglenews
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed beautifulsoup4-4.11.1 dateparser-0.7.6 feedparser-5.2.1 pygooglenews-0.1.2 requests-2.28.0

# %%
import requests
import pandas as pd
import re 
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession 
from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
import requests
import pandas as pd
import re 
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession 
from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
from PIL import Image
import requests
from io import BytesIO

import os, json, cv2, random

gn = GoogleNews()
search = gn.search('michael jackson')
i = 1
data = []
column = ['article_title', 'article_link', 'image_link(s)', 'image_caption(s)', 'classification(s)']
data.append(column)
for item in search['entries']:
    if i == 10:
        break
    column = []
    URL = item.link
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    links = []
    captions = []
    if(soup.find('title').text != ''):
        column.append(soup.find('title').text)
    elif (soup.find('h1').text != ''):
        column.append(soup.find('h1').text)
    column.append(URL)
    if (soup.findAll('img') != ' '):
        for link in soup.findAll('img'):
            captions.append(link.get('alt'))
            lelink = link.get('src')
            links.append(lelink)
            try:
                urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
            except:
                print('Mayday mayday')
    elif (soup.findAll('figure') != ' '):
        for link in soup.findAll('figure'):
            print('the img thing was empty')
            captions.append(link.get('alt'))
            lelink = link.get('src')
            links.append(lelink)
            try:
                urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
            except:
                print('Mayday mayday')
    column.append(links)
    column.append(captions)
    data.append(column)
    i = i + 1
import pandas as pd
column = ['article_title', 'article_link', 'image_link(s)', 'image_caption(s)', 'classification(s)']
df = pd.DataFrame(data, columns=column)
# Out:
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday
# Mayday mayday

# %%
df
# Out:
#                                        article_title  \
# 0                                      article_title
# 1  Chris Brown Addresses People Comparing Him to ...
# 2  Klay Thompson does great Michael Jackson dance...
# 3    Robins announces Heart, Michael Jackson trib...
# 4  Michael Jackson show brings alumni on stage | ...
# 5  Michael Jackson’s ‘Thriller’ Jacket Enters Roc...
# 6                                        nytimes.com
# 7  Michael Jackson's Daughter Paris Jackson Once ...
# 8  Paris Jackson, Prince Jackson Honor Michael Ja...
# 9  Myles Frost was born to play Michael Jackson. ...
#
#                                         article_link  \
# 0                                       article_link
# 1  https://www.complex.com/music/chris-brown-addr...
# 2  https://www.nbcsports.com/bayarea/warriors/kla...
# 3  https://www.tribtoday.com/life/ticket/2022/06/...
# 4  http://www.ladowntownnews.com/arts_and_enterta...
# 5  https://www.billboard.com/music/music-news/mic...
# 6  https://www.nytimes.com/2022/06/02/arts/dance/...
# 7  https://www.cheatsheet.com/entertainment/micha...
# 8  https://www.today.com/popculture/awards/paris-...
# 9  https://www.washingtonpost.com/theater-dance/2...
#
#                                        image_link(s)  \
# 0                                      image_link(s)
# 1  [data:image/svg+xml,%3Csvg xmlns="http://www.w...
# 2  [https://www.nbcsports.com/sites/rsnunited/fil...
# 3  [https://www.tribtoday.com/wp-content/themes/c...
# 4  [......
# 5  [https://www.facebook.com/tr?id=20465255320266...
# 6                                                 []
# 7  [https://www.cheatsheet.com/wp-content/uploads...
# 8  [https://media-cldnry.s-nbcnews.com/image/uplo...
# 9                                             [None]
#
#                                     image_caption(s)  classification(s)
# 0                                   image_caption(s)  classification(s)
# 1  [Chris Brown and Wizkid "Call Me Every Day", L...               None
# 2           [, Powered by Xfinity, None, , , , None]               None
# 3  [homepage logo, None, homepage logo, None, Non...               None
# 4  [, , Rodrigo Teaser, Rodrigo Teaser, Barenaked...               None
# 5  [None, None, Michael Jackson "Thriller", , Mic...               None
# 6                                                 []               None
# 7  [Showbiz Cheat Sheet, Paris Jackson performing...               None
# 8  [Food, Style, Health, Parenting, Home, Pop, Sh...               None
# 9                                                 []               None

# %%
# !pip3 install requests-html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html) (0.0.1)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests-html) (2.28.0)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Collecting urllib3<2.0.0,>=1.25.8
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 46.2 MB/s
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 54.6 MB/s
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.11.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.64.0)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (2022.6.15)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.8.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4->bs4->requests-html) (2.3.2.post1)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html) (4.2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html) (2.10)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from w3lib->requests-html) (1.15.0)
# Building wheels for collected packages: fake-useragent, parse
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=c422537e299ae53b4a195a6f2bdb670d213fbfc0da50c8f0f637c36ec6814851
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=486e176e8cabf594bee3e2bea1e1b92d742617ffbf815a2c8603d587ca439115
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent parse
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, pyquery, pyppeteer, parse, fake-useragent, requests-html
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 urllib3-1.26.9 w3lib-1.22.0 websockets-10.3
