# %% [markdown]
# # Reading in the JSON dataset
# The dataset obtained from Kaggle https://www.kaggle.com/datasets/rmisra/news-category-dataset?resource=download is in json format which has to be read in to python to be worked upon. However, the normal json.load was not working because of the format of the JSON file and so this solution was found on stackoverflow -> https://stackoverflow.com/questions/21058935/python-json-loads-shows-valueerror-extra-data

# %%
import json
news = []
for line in open('/Users/ben/Downloads/News_Category_Dataset_v2.json', 'r'):
    news.append(json.loads(line))

# with open('/Users/ben/Downloads/News_Category_Dataset_v2.json', 'r') as f:
#     data = json.load(f)

# %% [markdown]
# # Retrieving the images and captions from the article links in dataset
#
# The code below gets the the images and their corresponding captions for the articles from the links in the dataset from Kaggle obtained or found at the link -> https://www.kaggle.com/datasets/rmisra/news-category-dataset?resource=download ; right now it is not imposing any limits on the number of imahges to be obtained from the article and so it obtains almost all including non-relevant images like for advertisements. The number of images to be obtained could be limited to 10 per article so that superfluous images do not crawl in and ruin performance and statistical analysis. Right now working without a limit is going to kill my Mac

# %%
import requests
import pandas as pd
import re 
import json
from bs4 import BeautifulSoup
from requests_html import HTMLSession 
# from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
import requests
import pandas as pd
import re 

from bs4 import BeautifulSoup
from requests_html import HTMLSession 
# from pygooglenews import GoogleNews
import requests
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import urllib.request
from PIL import Image
import requests
from io import BytesIO

import os, json, random
# import cv2
# gn = GoogleNews()
# search = gn.search('sports')
i = 1
data = []
# the ranking of the article title and image caption for the image 
# the entailment relation between the article title and the image caption 
# maybe we can even figure out if there is some correlation between the entailment relation between the caption and the title of the article 
# and the relation of the caption and the image
# let us say that we are able to get a ranking but then what?
# how will we establish the relations?

# column = ['category', 'headline', 'authors', 'link', 'short descr', 'date', 'image_caption(s)', 'image_link(s)', 'classification(s)']
# data.append(column)

for thenews in news:
    if i % 10 == 0:
        print(f'episode {i}')
#     URL = item.link
    item = thenews['link']
    print(item)
    page = requests.get(item)
    soup = BeautifulSoup(page.content, "html.parser")
    links = []
    captions = []
    
    if (soup.findAll('img') != ' '):
        count = 0
        for link in soup.findAll('img'):
            count = count + 1
            column = []
            column.append(thenews['category'])
            column.append(thenews['headline'])
            column.append(thenews['authors'])
            column.append(thenews['link'])
            column.append(thenews['short_description'])
            column.append(thenews['date'])
#             if(soup.find('title').text != ''):
#                 column.append(soup.find('title').text)
#             elif (soup.find('h1').text != ''):
#                 column.append(soup.find('h1').text)
#             column.append(item)
            column.append(link.get('alt'))
            lelink = link.get('src')
            column.append(lelink)
#             try:
#                 urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
#             except:
#                 print('Deficiente')
            data.append(column)
            if(count == 10):
                break
    elif (soup.findAll('figure') != ' '):
        count = 0
        for link in soup.findAll('figure'):
            count = count + 1
            column = []
#             if(soup.find('title').text != ''):
#                 column.append(soup.find('title').text)
#             elif (soup.find('h1').text != ''):
#                 column.append(soup.find('h1').text)
            column.append(item)
            print('the img thing was empty')
            column.append(link.get('alt'))
            lelink = link.get('src')
            column.append(lelink)
#             try:
#                 urllib.request.urlretrieve(lelink, "input.jpg")
#             print("All good Houston")
#             img = Image.open("input.jpg")
#             img.show()
            
#             break
#             except:
#                 print('Mayday mayday')
    # column.append(links)
    # column.append(captions)
            data.append(column)
            if(count == 10):
                break
    i = i + 1
import pandas as pd
# column = ['article_title', 'article_link', 'image_link(s)', 'image_caption(s)', 'classification(s)']
column = ['category', 'headline', 'authors', 'link', 'short descr', 'date', 'image_caption(s)', 'image_link(s)']
df = pd.DataFrame(data, columns=column)
# Out:
# https://www.huffingtonpost.com/entry/texas-amanda-painter-mass-shooting_us_5b081ab4e4b0802d69caad89
# https://www.huffingtonpost.com/entry/will-smith-joins-diplo-and-nicky-jam-for-the-official-2018-world-cup-song_us_5b09726fe4b0fdb2aa541201
# https://www.huffingtonpost.com/entry/hugh-grant-marries_us_5b09212ce4b0568a880b9a8c
# https://www.huffingtonpost.com/entry/jim-carrey-adam-schiff-democrats_us_5b0950e8e4b0fdb2aa53e675
# https://www.huffingtonpost.com/entry/julianna-margulies-trump-poop-bag_us_5b093ec2e4b0fdb2aa53df70
# https://www.huffingtonpost.com/entry/morgan-freeman-devastated-sexual-misconduct_us_5b096319e4b0802d69cba298
# https://www.huffingtonpost.com/entry/donald-trump-mcondalds-tonight-show_us_5b093561e4b0fdb2aa53daba
# https://www.huffingtonpost.com/entry/amazon-prime-what-to-watch_us_5b044625e4b0c0b8b23ec14f
# https://www.huffingtonpost.com/entry/mike-myers-reveals-he-wants-to-do-a-fourth-austin-powers-film_us_5b096198e4b0802d69cb9f15
# episode 10
# https://www.huffingtonpost.com/entry/hulu-what-to-watch_us_5b0445bae4b0c0b8b23ec046
# https://www.huffingtonpost.com/entry/justin-timberlake-visits-texas-school-shooting-victims_us_5b098161e4b0fdb2aa54167e
# https://www.huffingtonpost.com/entry/south-korean-president-meets-north-koreas-kim-jong-un_us_5b094ebae4b0fdb2aa53e504
# https://www.huffingtonpost.com/entry/remote-oyster-growing-region-called-in-robots_us_5b083658e4b0fdb2aa53415d
# https://www.huffingtonpost.com/entry/immigrant-children-separated-from-parents_us_5b087b90e4b0802d69cb4070
# https://www.huffingtonpost.com/entry/fbi-wiretaps-putin-ally-trump-jr_us_5b08bf56e4b0568a880b7859
# https://www.huffingtonpost.com/entry/edward-snowden-trump-loves-putin_us_5b08ae41e4b0568a880b7451
# https://www.huffingtonpost.com/entry/obama-photog-pete-souza-trolls-trump-spy-claim_us_5b08f77ee4b0568a880b8752
# https://www.huffingtonpost.com/entry/results-for-irelands-historic-abortion-referendum-show-yes-vote-leads_us_5b086497e4b0802d69cb2cff
# https://www.huffingtonpost.com/entry/ryan-zinke-reel-back-critics-grand-pivot-conservation_us_5b086c78e4b0fdb2aa538b3f
# episode 20
# https://www.huffingtonpost.com/entry/trump-scottish-golf-resort-pays-women-less-than-men_us_5b08ca29e4b0802d69cb4d37
# https://www.huffingtonpost.com/entry/weird-fathers-day-gifts-2018_us_5b05bf18e4b05f0fc84438f6
# https://www.huffingtonpost.com/entry/twitter-put-star-wars-in-other-films_us_5b098875e4b0568a880be92c
# https://www.huffingtonpost.com/entry/montana-wolf-like-animal-mystery_us_5b04533de4b003dc7e4708af
# https://www.huffingtonpost.com/entry/north-korea-reax-canceled-summit_us_5b07a93de4b0568a8809ccf2
# https://www.huffingtonpost.com/entry/mississauga-canada-restaurant-bombing_us_5b079d47e4b0fdb2aa51f4dd
# https://www.huffingtonpost.com/entry/irish-traveled-home-vote-abortion_us_5b083753e4b0802d69cae69a
# https://www.huffingtonpost.com/entry/ireland-abortion-vote-exit-poll_us_5b087cebe4b0802d69cb40f1
# https://www.huffingtonpost.com/entry/warriors-coach-steve-kerr-nfl-ban-protests-fake-patriotism_us_5b082c41e4b0802d69cad469
# https://www.huffingtonpost.com/entry/mia-victory-barbados-elects-first-female-prime-minister-amor-mottley_us_5b0832eae4b0802d69cae087
# episode 30
# https://www.huffingtonpost.com/entry/police-killed-378-black-americans-colin-kaepernick_us_5b070160e4b07c4ea10655be
# https://www.huffingtonpost.com/entry/jack-johnson-taboo-sex-criminalized_us_5b08718be4b0802d69cb376a
# https://www.huffingtonpost.com/entry/bet-ceo-stepping-down-debra-lee_us_5b071754e4b07c4ea1066888
# https://www.huffingtonpost.com/entry/rachel-dolezal-charged-welfare-fraud_us_5b075ffae4b0568a8809a8c4
# https://www.huffingtonpost.com/entry/bishop-michael-curry-joins-christian-march-to-white-house-to-reclaim-jesus_us_5b07261ae4b0fdb2aa51b060
# https://www.huffingtonpost.com/entry/kanye-west-spent-85000-on-infamous-whitney-houston-photo-for-album-cover_us_5b08050be4b0fdb2aa52c2e7
# https://www.huffingtonpost.com/entry/morgan-freeman-sexual-harassment-sponsors-flee_us_5b078509e4b0802d69c99037
# https://www.huffingtonpost.com/entry/chinese-exclusion-act-immigration-politics_us_5b06a90fe4b05f0fc84552cf
# https://www.huffingtonpost.com/entry/trump-maga-swimsuits_us_5b07ae38e4b0802d69c9aae9
# https://www.huffingtonpost.com/entry/seth-meyers-donald-trump-north-korea_us_5b07cfb3e4b0802d69c9ea1f
# episode 40
# https://www.huffingtonpost.com/entry/stephen-colbert-michael-cohen-taxi-king_us_5b07654de4b0fdb2aa51da46
# https://www.huffingtonpost.com/entry/man-knife-stun-gun-muslim-students_us_5b084cece4b0802d69cb1ba8
# https://www.huffingtonpost.com/entry/jimmy-kimmel-ayatollah-tom-and-jerry_us_5b07e22ae4b0fdb2aa5284e2
# https://www.huffingtonpost.com/entry/indiana-middle-school-active-shooter_us_5b0811c2e4b0802d69ca90f2
# https://www.huffingtonpost.com/entry/nigerian-man-looks-like-chadwick-boseman_us_5b086b56e4b0fdb2aa538a92
# https://www.huffingtonpost.com/entry/david-cross-terrible-at-apologizing-jessica-walter_us_5b0813d8e4b0802d69ca9787
# https://www.huffingtonpost.com/entry/sesame-street-creators-sue-puppet-film-happytime-murders_us_5b0860fae4b0802d69cb2944
# https://www.huffingtonpost.com/entry/saddest-death-avengers-infinity-war_us_5af9dc8de4b0200bcab7d3e0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 43>()
#      47 item = thenews['link']
#      48 print(item)
# ---> 49 page = requests.get(item)
#      50 soup = BeautifulSoup(page.content, "html.parser")
#      51 links = []
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/sessions.py:667, in Session.send(self, request, **kwargs)
#     664 if allow_redirects:
#     665     # Redirect resolving generator.
#     666     gen = self.resolve_redirects(r, request, **kwargs)
# --> 667     history = [resp for resp in gen]
#     668 else:
#     669     history = []
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/sessions.py:667, in <listcomp>(.0)
#     664 if allow_redirects:
#     665     # Redirect resolving generator.
#     666     gen = self.resolve_redirects(r, request, **kwargs)
# --> 667     history = [resp for resp in gen]
#     668 else:
#     669     history = []
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/sessions.py:237, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     234     yield req
#     235 else:
# --> 237     resp = self.send(
#     238         req,
#     239         stream=stream,
#     240         timeout=timeout,
#     241         verify=verify,
#     242         cert=cert,
#     243         proxies=proxies,
#     244         allow_redirects=False,
#     245         **adapter_kwargs
#     246     )
#     248     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     250     # extract redirect url, if any, for the next loop
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
column = ['category', 'headline', 'authors', 'link', 'short descr', 'date', 'image_caption(s)', 'image_link(s)']
df = pd.DataFrame(data,columns=column)

# %%
df
# Out:
#           category                                           headline  \
# 0            CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1            CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 2            CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 3            CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 4            CRIME  There Were 2 Mass Shootings In Texas Last Week...
# ..             ...                                                ...
# 455  ENTERTAINMENT  'Sesame Street' Creators Sue Makers Of Upcomin...
# 456  ENTERTAINMENT  'Sesame Street' Creators Sue Makers Of Upcomin...
# 457  ENTERTAINMENT  'Sesame Street' Creators Sue Makers Of Upcomin...
# 458  ENTERTAINMENT  'Sesame Street' Creators Sue Makers Of Upcomin...
# 459  ENTERTAINMENT  'Sesame Street' Creators Sue Makers Of Upcomin...
#
#              authors                                               link  \
# 0    Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 2    Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 3    Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 4    Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# ..               ...                                                ...
# 455    Andy McDonald  https://www.huffingtonpost.com/entry/sesame-st...
# 456    Andy McDonald  https://www.huffingtonpost.com/entry/sesame-st...
# 457    Andy McDonald  https://www.huffingtonpost.com/entry/sesame-st...
# 458    Andy McDonald  https://www.huffingtonpost.com/entry/sesame-st...
# 459    Andy McDonald  https://www.huffingtonpost.com/entry/sesame-st...
#
#                                            short descr        date  \
# 0    She left her husband. He killed their children...  2018-05-26
# 1    She left her husband. He killed their children...  2018-05-26
# 2    She left her husband. He killed their children...  2018-05-26
# 3    She left her husband. He killed their children...  2018-05-26
# 4    She left her husband. He killed their children...  2018-05-26
# ..                                                 ...         ...
# 455  “The Happytime Murders” refers to the classic ...  2018-05-25
# 456  “The Happytime Murders” refers to the classic ...  2018-05-25
# 457  “The Happytime Murders” refers to the classic ...  2018-05-25
# 458  “The Happytime Murders” refers to the classic ...  2018-05-25
# 459  “The Happytime Murders” refers to the classic ...  2018-05-25
#
#                                       image_caption(s)  \
# 0    Amanda Painter is the sole survivor of a May 1...
# 1    Donna Bloom, director of legal services at Den...
# 2
# 3
# 4          Melissa Jeltsen - Senior Reporter, HuffPost
# ..                                                 ...
# 455
# 456
# 457
# 458
# 459
#
#                                          image_link(s)
# 0    https://img.huffingtonpost.com/asset/5b081b101...
# 1    https://img.huffingtonpost.com/asset/5b081d6c1...
# 2    https://img.huffingtonpost.com/asset/5b081c9f1...
# 3    https://img.huffingtonpost.com/asset/5b0844b51...
# 4    https://img.huffingtonpost.com/asset/5c1128ec2...
# ..                                                 ...
# 455  https://img.huffingtonpost.com/asset/62bad7102...
# 456  https://img.huffingtonpost.com/asset/62bacdd82...
# 457  https://img.huffingtonpost.com/asset/62bb42f12...
# 458  https://img.huffingtonpost.com/asset/62ba6cae2...
# 459  https://img.huffingtonpost.com/asset/62ba6cae2...
#
# [460 rows x 8 columns]

# %%
# Out:
# %{i}
