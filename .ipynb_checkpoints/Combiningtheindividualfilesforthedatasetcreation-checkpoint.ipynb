# %%
# !pwd
# %cd split_dataset/processed/witharticletextthe2000s
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/processed/witharticletextthe2000s

# %%
import os 
path = '/users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/processed/witharticletextthe2000s'
dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['processed_img_caption_withthe_article_data16800_to_16900.csv', 'processed_img_caption_withthe_article_data6000_to_6100.csv', 'processed_img_caption_withthe_article_data2900_to_3000.csv', 'processed_img_caption_withthe_article_data13700_to_13800.csv', 'processed_img_caption_withthe_article_data200_to_300.csv', 'processed_img_caption_withthe_article_data12000_to_12100.csv', 'processed_img_caption_withthe_article_data9100_to_9200.csv', 'processed_img_caption_withthe_article_data2300_to_2400.csv', 'processed_img_caption_withthe_article_data10600_to_10700.csv', 'processed_img_caption_withthe_article_data6400_to_6500.csv', 'processed_img_caption_withthe_article_data9300_to_9400.csv', 'processed_img_caption_withthe_article_data16200_to_16300.csv', 'processed_img_caption_withthe_article_data2000_to_2100.csv', 'processed_img_caption_withthe_article_data4000_to_4100.csv', 'processed_img_caption_withthe_article_data8300_to_8400.csv', 'processed_img_caption_withthe_article_data11900_to_12000.c
# ...

# %%
import pandas as pd
fin = pd.DataFrame()
count = 0
for file in dir_list:
    df = pd.read_csv(file)
    for i, row in df.iterrows():
        fin = fin.append(row)

# %%
fin.shape
# Out:
# (15055, 11)

# %%
# %cd split_dataset/processed/500sprocessed
import os 
path = '/users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/processed/500sprocessed'
dir_list = os.listdir(path)
print(dir_list)
for file in dir_list:
    df = pd.read_csv(file)
    for i, row in df.iterrows():
        fin = fin.append(row)
# Out:
# [Errno 2] No such file or directory: 'split_dataset/processed/500sprocessed'
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/processed/witharticletextthe2000s
# ['the500sprocessed.csv']

# %%
fin.shape
# Out:
# (15466, 11)

# %%
# !pwd
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/processed/witharticletextthe2000s

# %%
# %cd /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/tocombine
import os 
fin2 = pd.DataFrame()
path = '/users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/tocombine'
dir_list = os.listdir(path)
# print(dir_list)
for file in dir_list:
    print(file)
    df = pd.read_csv(file)
    for i, row in df.iterrows():
        fin2 = fin2.append(row)
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/tocombine
# unprocessed_img_caption_withthe_article_data88500_to_89000.csv
# unprocessed_img_caption_withthe_article_data170100_to_170600.csv
# unprocessed_img_caption_withthe_article_data133700_to_134200.csv
# unprocessed_img_caption_withthe_article_data164900_to_165400.csv
# unprocessed_img_caption_withthe_article_data133900_to_134400.csv
# unprocessed_img_caption_withthe_article_data144500_to_145000.csv
# unprocessed_img_caption_withthe_article_data96400_to_96900.csv
# unprocessed_img_caption_withthe_article_data149600_to_150100.csv
# unprocessed_img_caption_withthe_article_data132600_to_133100.csv
# unprocessed_img_caption_withthe_article_data169600_to_170100.csv
# unprocessed_img_caption_withthe_article_data122500_to_123000.csv
# unprocessed_img_caption_withthe_article_data75200_to_75700.csv
# unprocessed_img_caption_withthe_article_data163400_to_163900.csv
# ...

# %%
fin2.shape
# Out:
# (24801, 10)

# %%
fin = fin.drop(['Unnamed: 0.1'], axis=1)

# %%
finaldataset = pd.concat([fin, fin2], axis=0)

# %%
fin.shape
# Out:
# (15466, 10)

# %%
finaldataset.shape
# Out:
# (40267, 10)

# %%
finaldataset
# Out:
#     Unnamed: 0       category  \
# 0          0.0  ENTERTAINMENT
# 1          1.0          STYLE
# 2          2.0          STYLE
# 3          3.0  ENTERTAINMENT
# 4          4.0   QUEER VOICES
# ..         ...            ...
# 17        17.0       POLITICS
# 18        18.0   BLACK VOICES
# 19        19.0  ENTERTAINMENT
# 20        20.0  ENTERTAINMENT
# 21        21.0       POLITICS
#
#                                              headline           authors  \
# 0   First He Made Movies About ‘Strong, Feisty Wom...    Matthew Jacobs
# 1   Prince Harry Opens Up About His 'Fantastic' Ch...   Carly Ledbetter
# 2   Prince Harry Opens Up About His 'Fantastic' Ch...   Carly Ledbetter
# 3   Mark Hamill Is Sorry For Slamming Luke Skywalk...     Elyse Wanshel
# 4   Ryan Murphy's Inclusive, History-Making Series...    Curtis M. Wong
# ..                                                ...               ...
# 17  Marco Rubio Tries To Salvage His Campaign With...      Eliot Nelson
# ...

# %%
categories = finaldataset.groupby(['category'])['category'].count().tolist()

# %%
categories
# Out:
# [326,
#  445,
#  1292,
#  1350,
#  247,
#  254,
#  1086,
#  79,
#  385,
#  176,
#  3606,
#  149,
#  231,
#  427,
#  222,
#  828,
#  904,
#  160,
#  919,
#  300,
#  814,
#  148,
#  475,
#  828,
#  10872,
#  1181,
#  867,
#  521,
#  1526,
#  443,
#  483,
#  619,
#  377,
#  2221,
#  1124,
#  265,
#  442,
#  854,
#  820,
#  1077,
#  924]

# %%
finaldataset.groupby(['category'])['category'].count()
# Out:
# category
# ARTS                326
# ARTS & CULTURE      445
# BLACK VOICES       1292
# BUSINESS           1350
# COLLEGE             247
# COMEDY              254
# CRIME              1086
# CULTURE & ARTS       79
# DIVORCE             385
# EDUCATION           176
# ENTERTAINMENT      3606
# ENVIRONMENT         149
# FIFTY               231
# FOOD & DRINK        427
# GOOD NEWS           222
# GREEN               828
# HEALTHY LIVING      904
# HOME & LIVING       160
# IMPACT              919
# LATINO VOICES       300
# MEDIA               814
# MONEY               148
# PARENTING           475
# PARENTS             828
# POLITICS          10872
# QUEER VOICES       1181
# RELIGION            867
# SCIENCE             521
# SPORTS             1526
# STYLE               443
# STYLE & BEAUTY      483
# TASTE               619
# TECH                377
# THE WORLDPOST      2221
# TRAVEL             1124
# WEDDINGS            265
# WEIRD NEWS          442
# WELLNESS            854
# ...

# %%
finaldataset.to_csv('PREFINALDATASETCATEGORIESNOTCOMBINED.csv')
