# %% [markdown]
# # Preprocessing the data
#
# The data till 44K did not have the article text scraped at the same time; so we shall go through those datasets and filter out the ones which have image caption length lesser than 100 characters. Then they would be put into the article scraping code to get the article text.
#
# The other files having 500 data points each have the article text as well which later have to be preprocessed with regard to the image caption length as for the above. The reason why this time the article text was scraped at the same time is because image caption preprocessing does not require us to access the site again whereas article text scraping does so it is better to scrape it at the same time as the image caption and stuff (even though it leads to a lot of data being gathered unneccesarily); could also have performed the preprocessing of image caption at the same time. So for the next ones did that, after checking caption length only we get any of the stuff inside along with the article text

# %%
# %cd /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the2000
# for some reason, using ! does not work to change the directory
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the2000

# %%
# !pwd
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the2000

# %%
import os 
path = '/users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the2000/'
dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['unprocessed_img_caption_article_data36000_to_41000.csv', 'unprocessed_img_caption_article_data28000_to_33000.csv', 'unprocessed_img_caption_article_data10000_to_15000.csv', 'unprocessed_img_caption_article_data34000_to_39000.csv', 'unprocessed_img_caption_article_data16000_to_21000.csv', 'unprocessed_img_caption_article_data30000_to_35000.csv', 'unprocessed_img_caption_article_data32000_to_37000.csv', 'unprocessed_img_caption_article_data4000_to_9000.csv', 'unprocessed_img_caption_article_data24000_to_29000.csv', 'unprocessed_img_caption_article_data12000_to_17000.csv', 'unprocessed_img_caption_article_data42000_to_47000.csv', 'unprocessed_img_caption_article_data18000_to_23000.csv', 'unprocessed_img_caption_article_data22000_to_27000.csv', 'unprocessed_img_caption_article_data14000_to_19000.csv', 'unprocessed_img_caption_article_data26000_to_31000.csv', 'unprocessed_img_caption_article_data38000_to_43000.csv', 'unprocessed_img_caption_article_data20000_to_25000.csv', 'unprocessed_
# ...

# %%
import pandas as pd
fin = pd.DataFrame()
count = 0
for file in dir_list:
    df = pd.read_csv(file)
    for i, row in df.iterrows():
        if len(str(row['image_caption(s)'])) >= 50:
            fin = fin.append(row)
# Out:
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# ...

# %%
fin
# Out:
#       Unnamed: 0       category  \
# 13            13       POLITICS
# 16            16  THE WORLDPOST
# 31            31       POLITICS
# 34            34       POLITICS
# 35            35       POLITICS
# ...          ...            ...
# 5951        5951        COLLEGE
# 5962        5962        SCIENCE
# 5963        5963        SCIENCE
# 5968        5968          CRIME
# 5977        5977       POLITICS
#
#                                                headline          authors  \
# 13    Sad Inauguration Workers Prepare To Celebrate ...    Amanda Terkel
# 16    Fuel Truck Blast Kills Dozens In North Syrian ...              NaN
# 31    How Virginia Gubernatorial Hopeful Tom Perriel...        Ryan Grim
# 34    How Obama Took An Existing Feminist Law And Ma...   Travis Waldron
# 35    How Obama Took An Existing Feminist Law And Ma...   Travis Waldron
# ...                                                 ...              ...
# ...

# %%
fin.to_csv('the2000sprocessed.csv')

# %% [markdown]
# After this have to process the ones in the the500unproccessedcaptions and have to just keep the ones which have length greater than 50; after this the ones being collected have the article data as well and are also filtered according to the caption length

# %%
# %cd /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the500unprocessedcaptions
# Out:
# /users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the500unprocessedcaptions

# %%
import os 
path = '/users/pgrad/mittalan/Desktop/dissertation/dissertation2022/split_dataset/the500unprocessedcaptions/'

dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['unprocessed_img_caption_withthe_article_data44500_to_45000.csv', 'unprocessed_img_caption_withthe_article_data44000_to_44500.csv']

# %%
import pandas as pd
fin = pd.DataFrame()
count = 0
for file in dir_list:
    df = pd.read_csv(file)
    for i, row in df.iterrows():
        if len(str(row['image_caption(s)'])) >= 50:
            fin = fin.append(row)
# Out:
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# /tmp/ipykernel_818010/579057699.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fin = fin.append(row)
# ...

# %%
fin.to_csv('the500sprocessed.csv')
